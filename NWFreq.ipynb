# %%
import pandas as pd
import sqlite3
from mlxtend.frequent_patterns import apriori,association_rules
import pyodbc

# %%
DB2 = {'servername': 'LAPTOP-OGICI52C\\SQLEXPRESS',
       'database': 'Northwind'}

export_conn_adventurewors = pyodbc.connect('DRIVER={SQL Server};SERVER='+ DB2['servername'] + ';DATABASE=' + DB2['database'] + ';Trusted_Connection=yes')

# %%
nw_df_product = pd.read_sql_query("SELECT * from Products",export_conn_adventurewors)
nw_df_orderdetails = pd.read_sql_query("SELECT * from Order_Details",export_conn_adventurewors)
df = pd.merge(nw_df_orderdetails, nw_df_product, on= 'ProductID')
df
# Out:
# C:\Users\harre\AppData\Local\Temp\ipykernel_13244\975679014.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   nw_df_product = pd.read_sql_query("SELECT * from Products",export_conn_adventurewors)
# C:\Users\harre\AppData\Local\Temp\ipykernel_13244\975679014.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   nw_df_orderdetails = pd.read_sql_query("SELECT * from Order_Details",export_conn_adventurewors)
#       OrderID  ProductID  UnitPrice_x  Quantity  Discount      ProductName  \
# 0       10248         11         14.0        12      0.00   Queso Cabrales
# 1       10296         11         16.8        12      0.00   Queso Cabrales
# 2       10327         11         16.8        50      0.20   Queso Cabrales
# 3       10353         11         16.8        12      0.20   Queso Cabrales
# 4       10365         11         16.8        24      0.00   Queso Cabrales
# ...       ...        ...          ...       ...       ...              ...
# 2150    10420          9         77.6        20      0.10  Mishi Kobe Niku
# 2151    10515          9         97.0        16      0.15  Mishi Kobe Niku
# 2152    10687          9         97.0        50      0.25  Mishi Kobe Niku
# 2153    10693          9         97.0         6      0.00  Mishi Kobe Niku
# 2154    10848          9         97.0         3      0.00  Mishi Kobe Niku
#
#       SupplierID  CategoryID   QuantityPerUnit  UnitPrice_y  UnitsInStock  \
# 0              5           4         1 kg pkg.         21.0            22
# 1              5           4         1 kg pkg.         21.0            22
# 2              5           4         1 kg pkg.         21.0            22
# 3              5           4         1 kg pkg.         21.0            22
# 4              5           4         1 kg pkg.         21.0            22
# ...          ...         ...               ...          ...           ...
# 2150           4           6  18 - 500 g pkgs.         97.0            29
# 2151           4           6  18 - 500 g pkgs.         97.0            29
# 2152           4           6  18 - 500 g pkgs.         97.0            29
# 2153           4           6  18 - 500 g pkgs.         97.0            29
# 2154           4           6  18 - 500 g pkgs.         97.0            29
#
#       UnitsOnOrder  ReorderLevel  Discontinued
# 0               30            30         False
# 1               30            30         False
# 2               30            30         False
# 3               30            30         False
# 4               30            30         False
# ...            ...           ...           ...
# 2150             0             0          True
# 2151             0             0          True
# 2152             0             0          True
# 2153             0             0          True
# 2154             0             0          True
#
# [2155 rows x 14 columns]

# %%
df_werk = (df[df['Discontinued'] == False]
           .groupby(['OrderID', 'ProductName'])['Quantity']
           .sum()
           .unstack()
           .reset_index()
           .fillna(0)
           .set_index('OrderID'))
df_werk
# Out:
# ProductName  Aniseed Syrup  Boston Crab Meat  Camembert Pierrot  \
# OrderID
# 10248                  0.0               0.0                0.0
# 10249                  0.0               0.0                0.0
# 10250                  0.0               0.0                0.0
# 10251                  0.0               0.0                0.0
# 10252                  0.0               0.0               40.0
# ...                    ...               ...                ...
# 11073                  0.0               0.0                0.0
# 11074                  0.0               0.0                0.0
# 11075                  0.0               0.0                0.0
# 11076                  0.0               0.0                0.0
# 11077                  4.0               0.0                2.0
#
# ProductName  Carnarvon Tigers  Chai  Chang  Chartreuse verte  \
# OrderID
# 10248                     0.0   0.0    0.0               0.0
# 10249                     0.0   0.0    0.0               0.0
# 10250                     0.0   0.0    0.0               0.0
# 10251                     0.0   0.0    0.0               0.0
# 10252                     0.0   0.0    0.0               0.0
# ...                       ...   ...    ...               ...
# 11073                     0.0   0.0    0.0               0.0
# 11074                     0.0   0.0    0.0               0.0
# 11075                     0.0   0.0   10.0               0.0
# 11076                     0.0   0.0    0.0               0.0
# 11077                     0.0   0.0   24.0               2.0
#
# ProductName  Chef Anton's Cajun Seasoning  Chocolade  Côte de Blaye  ...  \
# OrderID                                                              ...
# 10248                                 0.0        0.0            0.0  ...
# 10249                                 0.0        0.0            0.0  ...
# 10250                                 0.0        0.0            0.0  ...
# 10251                                 0.0        0.0            0.0  ...
# 10252                                 0.0        0.0            0.0  ...
# ...                                   ...        ...            ...  ...
# 11073                                 0.0        0.0            0.0  ...
# 11074                                 0.0        0.0            0.0  ...
# 11075                                 0.0        0.0            0.0  ...
# 11076                                 0.0        0.0            0.0  ...
# 11077                                 1.0        0.0            0.0  ...
#
# ProductName  Tarte au sucre  Teatime Chocolate Biscuits  Tofu  Tourtière  \
# OrderID
# 10248                   0.0                         0.0   0.0        0.0
# 10249                   0.0                         0.0   9.0        0.0
# 10250                   0.0                         0.0   0.0        0.0
# 10251                   0.0                         0.0   0.0        0.0
# 10252                   0.0                         0.0   0.0        0.0
# ...                     ...                         ...   ...        ...
# 11073                   0.0                         0.0   0.0        0.0
# 11074                   0.0                         0.0   0.0        0.0
# 11075                   0.0                         0.0   0.0        0.0
# 11076                   0.0                        10.0  20.0        0.0
# 11077                   0.0                         0.0   1.0        0.0
#
# ProductName  Tunnbröd  Uncle Bob's Organic Dried Pears  Valkoinen suklaa  \
# OrderID
# 10248             0.0                              0.0               0.0
# 10249             0.0                              0.0               0.0
# 10250             0.0                              0.0               0.0
# 10251             0.0                              0.0               0.0
# 10252             0.0                              0.0               0.0
# ...               ...                              ...               ...
# 11073             0.0                              0.0               0.0
# 11074             0.0                              0.0               0.0
# 11075             0.0                              0.0               0.0
# 11076             0.0                              0.0               0.0
# 11077             2.0                              1.0               0.0
#
# ProductName  Vegie-spread  Wimmers gute Semmelknödel  Zaanse koeken
# OrderID
# 10248                 0.0                        0.0            0.0
# 10249                 0.0                        0.0            0.0
# 10250                 0.0                        0.0            0.0
# 10251                 0.0                        0.0            0.0
# 10252                 0.0                        0.0            0.0
# ...                   ...                        ...            ...
# 11073                 0.0                        0.0            0.0
# 11074                 0.0                        0.0            0.0
# 11075                 0.0                        0.0            0.0
# 11076                 0.0                        0.0            0.0
# 11077                 0.0                        2.0            0.0
#
# [815 rows x 69 columns]

# %%
def hot_encode(x):
       try:
              x = float(x)  # Converteer x naar float
       except ValueError:
              return 0  # Of een andere waarde voor niet-numerieke invoer

       if x <= 0:
              return 0
       if x >= 1:
              return 1
       return x

# Pas de functie toe op de gehele DataFrame
basket_encoded = df_werk.applymap(hot_encode)
df = basket_encoded
df
# Out:
# ProductName  Aniseed Syrup  Boston Crab Meat  Camembert Pierrot  \
# OrderID
# 10248                    0                 0                  0
# 10249                    0                 0                  0
# 10250                    0                 0                  0
# 10251                    0                 0                  0
# 10252                    0                 0                  1
# ...                    ...               ...                ...
# 11073                    0                 0                  0
# 11074                    0                 0                  0
# 11075                    0                 0                  0
# 11076                    0                 0                  0
# 11077                    1                 0                  1
#
# ProductName  Carnarvon Tigers  Chai  Chang  Chartreuse verte  \
# OrderID
# 10248                       0     0      0                 0
# 10249                       0     0      0                 0
# 10250                       0     0      0                 0
# 10251                       0     0      0                 0
# 10252                       0     0      0                 0
# ...                       ...   ...    ...               ...
# 11073                       0     0      0                 0
# 11074                       0     0      0                 0
# 11075                       0     0      1                 0
# 11076                       0     0      0                 0
# 11077                       0     0      1                 1
#
# ProductName  Chef Anton's Cajun Seasoning  Chocolade  Côte de Blaye  ...  \
# OrderID                                                              ...
# 10248                                   0          0              0  ...
# 10249                                   0          0              0  ...
# 10250                                   0          0              0  ...
# 10251                                   0          0              0  ...
# 10252                                   0          0              0  ...
# ...                                   ...        ...            ...  ...
# 11073                                   0          0              0  ...
# 11074                                   0          0              0  ...
# 11075                                   0          0              0  ...
# 11076                                   0          0              0  ...
# 11077                                   1          0              0  ...
#
# ProductName  Tarte au sucre  Teatime Chocolate Biscuits  Tofu  Tourtière  \
# OrderID
# 10248                     0                           0     0          0
# 10249                     0                           0     1          0
# 10250                     0                           0     0          0
# 10251                     0                           0     0          0
# 10252                     0                           0     0          0
# ...                     ...                         ...   ...        ...
# 11073                     0                           0     0          0
# 11074                     0                           0     0          0
# 11075                     0                           0     0          0
# 11076                     0                           1     1          0
# 11077                     0                           0     1          0
#
# ProductName  Tunnbröd  Uncle Bob's Organic Dried Pears  Valkoinen suklaa  \
# OrderID
# 10248               0                                0                 0
# 10249               0                                0                 0
# 10250               0                                0                 0
# 10251               0                                0                 0
# 10252               0                                0                 0
# ...               ...                              ...               ...
# 11073               0                                0                 0
# 11074               0                                0                 0
# 11075               0                                0                 0
# 11076               0                                0                 0
# 11077               1                                1                 0
#
# ProductName  Vegie-spread  Wimmers gute Semmelknödel  Zaanse koeken
# OrderID
# 10248                   0                          0              0
# 10249                   0                          0              0
# 10250                   0                          0              0
# 10251                   0                          0              0
# 10252                   0                          0              0
# ...                   ...                        ...            ...
# 11073                   0                          0              0
# 11074                   0                          0              0
# 11075                   0                          0              0
# 11076                   0                          0              0
# 11077                   0                          1              0
#
# [815 rows x 69 columns]

# %%
# Deze regel gebruikt het Apriori-algoritme om frequente itemsets te vinden in de DataFrame df.
# min_support = 0.01 geeft de minimumsupportdrempel aan waaraan een itemset moet voldoen om als frequent te worden beschouwd.
# use_colnames = True geeft aan dat kolomnamen moeten worden gebruikt in de uitvoer DataFrame
frq_items = apriori(df, min_support=0.007, use_colnames=True)

# Deze regel genereert associatieregels uit de frequente itemsets frq_items.
# De parameter metric geeft aan welke maatstaf moet worden gebruikt om de gegenereerde regels te evalueren, hier is "lift" gekozen.
# min_threshold = 1 stelt de minimumdrempel in voor de evaluatiemaatstaf. In dit geval worden regels met een lift groter dan of gelijk aan 1 beschouwd.
rules = association_rules(frq_items, metric="lift", min_threshold=1)

# Deze regel sorteert de gegenereerde associatieregels op twee criteria: confidence en lift.
# ascending =[False, False] geeft aan dat de sorteer volgorde voor zowel confidence als lift aflopend is (van hoog naar laag).
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
rules
# Out:
# C:\Users\harre\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                  antecedents               consequents  antecedent support  \
# 13          (Sirop d'érable)     (Sir Rodney's Scones)            0.029448
# 12     (Sir Rodney's Scones)          (Sirop d'érable)            0.047853
# 9    (Nord-Ost Matjeshering)               (Tourtière)            0.039264
# 8                (Tourtière)   (Nord-Ost Matjeshering)            0.044172
# 6                  (Pavlova)       (Gorgonzola Telino)            0.052761
# 4   (Mozzarella di Giovanni)       (Gorgonzola Telino)            0.046626
# 1              (Flotemysost)       (Camembert Pierrot)            0.051534
# 10                 (Pavlova)          (Tarte au sucre)            0.052761
# 2                  (Pavlova)       (Camembert Pierrot)            0.052761
# 7        (Gorgonzola Telino)                 (Pavlova)            0.062577
# 11          (Tarte au sucre)                 (Pavlova)            0.058896
# 5        (Gorgonzola Telino)  (Mozzarella di Giovanni)            0.062577
# 0        (Camembert Pierrot)             (Flotemysost)            0.062577
# 3        (Camembert Pierrot)                 (Pavlova)            0.062577
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 13            0.047853  0.009816    0.333333  6.965812  0.008407    1.428221
# 12            0.029448  0.009816    0.205128  6.965812  0.008407    1.221017
# 9             0.044172  0.007362    0.187500  4.244792  0.005628    1.176404
# 8             0.039264  0.007362    0.166667  4.244792  0.005628    1.152883
# 6             0.062577  0.008589    0.162791  2.601459  0.005287    1.119700
# 4             0.062577  0.007362    0.157895  2.523220  0.004444    1.113190
# 1             0.062577  0.007362    0.142857  2.282913  0.004137    1.093661
# 10            0.058896  0.007362    0.139535  2.369186  0.004255    1.093716
# 2             0.062577  0.007362    0.139535  2.229822  0.004060    1.089438
# 7             0.052761  0.008589    0.137255  2.601459  0.005287    1.097936
# 11            0.052761  0.007362    0.125000  2.369186  0.004255    1.082559
# 5             0.046626  0.007362    0.117647  2.523220  0.004444    1.080491
# 0             0.051534  0.007362    0.117647  2.282913  0.004137    1.074928
# 3             0.052761  0.007362    0.117647  2.229822  0.004060    1.073538
#
#     zhangs_metric
# 13       0.882427
# 12       0.899485
# 9        0.795658
# 8        0.799743
# 6        0.649889
# 4        0.633205
# 1        0.592497
# 10       0.610104
# 2        0.582254
# 7        0.656694
# 11       0.614081
# 5        0.643979
# 0        0.599476
# 3        0.588351
